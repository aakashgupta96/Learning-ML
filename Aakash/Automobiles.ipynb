# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
from sklearn import model_selection as cv

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# - Load dataset

# %%
df = pd.read_csv("../data/autos.csv", encoding='latin-1')

# %%
del df["nrOfPictures"],df["lastSeen"],df["dateCreated"],df["name"],df["dateCrawled"], df["postalCode"], df["model"], df["monthOfRegistration"]

# %%
#Shifting price column to last column in df
price = df["price"].copy()
del df["price"]
df["price"] = price

# %% [markdown]
# - Removing null entries

# %%
df.isnull().sum()
# Out:
# seller                    0
# offerType                 0
# abtest                    0
# vehicleType           37869
# yearOfRegistration        0
# gearbox               20209
# powerPS                   0
# kilometer                 0
# fuelType              33386
# brand                     0
# notRepairedDamage     72060
# price                     0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#         seller offerType   abtest vehicleType  yearOfRegistration    gearbox  \
# 1       privat   Angebot     test       coupe                2011    manuell
# 3       privat   Angebot     test  kleinwagen                2001    manuell
# 4       privat   Angebot     test  kleinwagen                2008    manuell
# 5       privat   Angebot     test   limousine                1995    manuell
# 6       privat   Angebot     test      cabrio                2004    manuell
# 7       privat   Angebot     test   limousine                1980    manuell
# 10      privat   Angebot  control   limousine                2004    manuell
# 11      privat   Angebot  control       kombi                2005    manuell
# 14      privat   Angebot  control         suv                2011    manuell
# 17      privat   Angebot  control  kleinwagen                2004  automatik
# 18      privat   Angebot     test         bus                2007    manuell
# 19      privat   Angebot     test         bus                2004    manuell
# 20      privat   Angebot  control       coupe                2009    manuell
# 21      privat   Angebot     test   limousine                2002  automatik
# 23      privat   Angebot     test  kleinwagen                1997    manuell
# 24      privat   Angebot     test   limousine                1990    manuell
# 25      privat   Angebot  control       kombi                2002  automatik
# 27      privat   Angebot     test   limousine                2008    manuell
# 28      privat   Angebot     test         bus                1981    manuell
# 29      privat   Angebot     test  kleinwagen                2003    manuell
# 30      privat   Angebot     test   limousine                1995  automatik
# 33      privat   Angebot     test   limousine                2007  automatik
# 34      privat   Angebot  control   limousine                2004  automatik
# 38      privat   Angebot     test      andere                2002    manuell
# 39      privat   Angebot     test         bus                1984    manuell
# 43      privat   Angebot     test   limousine                2007    manuell
# 45      privat   Angebot  control  kleinwagen                1999    manuell
# 46      privat   Angebot  control   limousine                2007    manuell
# 47      privat   Angebot     test       kombi                1998  automatik
# 49      privat   Angebot     test         bus                2012  automatik
# ...        ...       ...      ...         ...                 ...        ...
# 371480  privat   Angebot  control      cabrio                2006  automatik
# 371481  privat   Angebot  control      cabrio                1991    manuell
# 371483  privat   Angebot  control   limousine                2012  automatik
# 371487  privat   Angebot     test   limousine                2002  automatik
# 371488  privat   Angebot     test       coupe                2003    manuell
# 371489  privat   Angebot     test         bus                2007    manuell
# 371490  privat   Angebot  control       kombi                2012    manuell
# 371491  privat   Angebot     test   limousine                2002    manuell
# 371492  privat   Angebot     test  kleinwagen                1997  automatik
# 371497  privat   Angebot  control       kombi                2008    manuell
# 371499  privat   Angebot  control  kleinwagen                1998    manuell
# 371500  privat   Angebot     test   limousine                2014  automatik
# 371501  privat   Angebot     test         bus                2003  automatik
# 371502  privat   Angebot     test       kombi                1998    manuell
# 371503  privat   Angebot  control  kleinwagen                1999    manuell
# 371505  privat   Angebot     test       kombi                2000    manuell
# 371506  privat   Angebot     test   limousine                2006    manuell
# 371508  privat   Angebot  control   limousine                2001    manuell
# 371510  privat   Angebot     test   limousine                2003  automatik
# 371511  privat   Angebot  control   limousine                1997    manuell
# 371512  privat   Angebot     test   limousine                2003  automatik
# 371513  privat   Angebot  control   limousine                2008    manuell
# 371516  privat   Angebot  control  kleinwagen                1998    manuell
# 371517  privat   Angebot     test   limousine                2010    manuell
# 371518  privat   Angebot     test       kombi                2005    manuell
# 371520  privat   Angebot  control   limousine                2004    manuell
# 371521  privat   Angebot  control         bus                2000    manuell
# 371524  privat   Angebot     test      cabrio                2000  automatik
# 371525  privat   Angebot     test         bus                1996    manuell
# 371527  privat   Angebot  control   limousine                2013    manuell
#
#         powerPS  kilometer fuelType          brand notRepairedDamage  price
# 1           190     125000   diesel           audi                ja  18300
# 3            75     150000   benzin     volkswagen              nein   1500
# 4            69      90000   diesel          skoda              nein   3600
# 5           102     150000   benzin            bmw                ja    650
# 6           109     150000   benzin        peugeot              nein   2200
# 7            50      40000   benzin     volkswagen              nein      0
# 10          105     150000   benzin          mazda              nein   2000
# 11          140     150000   diesel     volkswagen                ja   2799
# 14          190      70000   diesel         nissan              nein  17999
# 17           75     150000   benzin        renault              nein   1750
# 18          136     150000   diesel           ford              nein   7550
# 19          102     150000   benzin  mercedes_benz              nein   1850
# 20          160     100000   benzin     volkswagen              nein  10400
# 21          231     150000   benzin            bmw              nein   3699
# 23           50     150000   benzin           seat              nein    450
# 24          118     150000   benzin  mercedes_benz                ja    500
# 25          193     150000   diesel            bmw                ja   2500
# 27           99      60000   benzin          honda              nein   6900
# 28           50       5000   benzin     volkswagen              nein   1990
# 29           60     150000   benzin           fiat              nein    690
# 30          113     150000   diesel  mercedes_benz              nein   3300
# 33          218      20000   benzin            bmw              nein  18000
# 34          122     150000   diesel  mercedes_benz              nein   3500
# 38          129     150000   diesel     volkswagen              nein  11900
# 39           70     150000   diesel  mercedes_benz              nein   1500
# 43           95     100000   benzin           mini              nein   6990
# 45           75     125000   benzin        renault              nein    590
# 46          177     150000   diesel            bmw              nein   7999
# 47          193     150000   benzin            bmw              nein   2100
# 49          109     150000   diesel  mercedes_benz              nein  13500
# ...         ...        ...      ...            ...               ...    ...
# 371480       82     125000   benzin          smart              nein   4499
# 371481      211     150000   benzin        porsche              nein  12800
# 371483      136      60000   diesel  mercedes_benz              nein  20500
# 371487      177     150000   diesel  mercedes_benz                ja   3800
# 371488      143     150000   benzin  mercedes_benz                ja   2999
# 371489        0     125000   benzin  mercedes_benz              nein   7900
# 371490      156     125000   benzin          honda              nein  13850
# 371491      116     150000      lpg     volkswagen              nein   3200
# 371492        0     100000   benzin           opel                ja    390
# 371497      116     150000   benzin           opel              nein   4900
# 371499       54     150000   benzin           opel              nein    600
# 371500      150      30000   benzin     volkswagen              nein  20400
# 371501      174     150000   benzin       chrysler              nein   3900
# 371502      125     150000   benzin           audi              nein   1600
# 371503       68      70000   benzin         subaru              nein   1700
# 371505      101     150000   benzin           opel                ja    800
# 371506      105     150000   diesel     volkswagen              nein   5900
# 371508      125     150000   benzin           opel              nein   1400
# 371510      145     150000   diesel  mercedes_benz              nein   6500
# 371511      150     150000   benzin           audi              nein   1999
# 371512      260     150000   diesel  mercedes_benz                ja   5000
# 371513      105     150000   diesel           seat              nein   4400
# 371516       50     150000   benzin     volkswagen              nein   1490
# 371517      140     150000   diesel     volkswagen              nein   7900
# 371518        3     150000   diesel            bmw              nein   3999
# 371520      225     150000   benzin           seat                ja   3200
# 371521        0     150000   benzin           opel              nein   1150
# 371524      101     125000   benzin          smart              nein   1199
# 371525      102     150000   diesel     volkswagen              nein   9200
# 371527      320      50000   benzin            bmw              nein  28990
#
# [268012 rows x 12 columns]

# %% [markdown]
# - Set X,Y variable using dataframe

# %%
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1].values

# %% [markdown]
# - Label Encoding to change strings to integers

# %%
labelEncoder_Seller = LabelEncoder()
X[:,0] = labelEncoder_Seller.fit_transform(X[:,0])
print(len(labelEncoder_Seller.classes_))

labelEncoder_OfferType = LabelEncoder()
X[:,1] = labelEncoder_OfferType.fit_transform(X[:,1])
print(len(labelEncoder_OfferType.classes_))

labelEncoder_AbTest = LabelEncoder()
X[:,2] = labelEncoder_AbTest.fit_transform(X[:,2])
print(len(labelEncoder_AbTest.classes_))

labelEncoder_VehicleType = LabelEncoder()
X[:,3] = labelEncoder_VehicleType.fit_transform(X[:,3])
print(len(labelEncoder_VehicleType.classes_))

labelEncoder_Gearbox = LabelEncoder()
X[:,5] = labelEncoder_Gearbox.fit_transform(X[:,5])
print(len(labelEncoder_Gearbox.classes_))

labelEncoder_FuelType = LabelEncoder()
X[:,8] = labelEncoder_FuelType.fit_transform(X[:,8])
print(len(labelEncoder_FuelType.classes_))

labelEncoder_Brand = LabelEncoder()
X[:,9] = labelEncoder_Brand.fit_transform(X[:,9])
print(len(labelEncoder_Brand.classes_))

labelEncoder_NotRepairedDamage = LabelEncoder()
X[:,10] = labelEncoder_NotRepairedDamage.fit_transform(X[:,10])
print(len(labelEncoder_NotRepairedDamage.classes_))
# Out:
# 2
# 2
# 2
# 8
# 2
# 7
# 40
# 2

# %% [markdown]
# - One Hot Encoding to change categorical integers to dummy variables

# %%
oneHotEncoder = OneHotEncoder(categorical_features = [0,1,2,3,5,8,9,10])
X = oneHotEncoder.fit_transform(X).toarray()
#This will add the dummy features in order of passed array above and will place uncategorical features to last in same order.

# %% [markdown]
# - Avoiding Dummy Variable Trap

# %%
#Taking one less dummy variable from each set of categorical dummy variables
removed_columns =  set([1,3,5,13,15,22,62,64])
all_columns = set(range(0,68))
X = X[:,list(all_columns - removed_columns)]

# %% [markdown]
# - Using Standard Scalar to scale features

# %%
sc_X = StandardScaler()
X = sc_X.fit_transform(X)

# %% [markdown]
# # 2. Without Backward Elmination

# %%
X_train, X_test, Y_train, Y_test = cv.train_test_split(X,Y,test_size=0.25,random_state=0)
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
regressor.score(X_test,Y_test)
# Out:
# 3.242998639008121e-05

# %% [markdown]
# ## 3. Using Backward Elimination

# %% [markdown]
# #### Step 1 (Selecting Significance Level)

# %%
#Adding column of 1s for constant
X = np.append(arr = np.ones((X.shape[0],1)).astype(int),values = X,axis=1)
significance_level = 0.05

# %% [markdown]
# #### Step 2 (Include all features)

# %%
included_columns = [i for i in range(X.shape[-1])]

# %% [markdown]
# #### Step 3 and Step 4 (Fit Model with features available in included_columns and find p values for all untill all p values are less than significance level)

# %%
finished = False
while not finished:
    X_opt = X[:,included_columns]
    regressor_OLS = sm.OLS(endog=Y,exog=X_opt).fit()
    #print(regressor_OLS.summary())
    table_data = regressor_OLS.summary().tables[1].data
    p_values = [float(table_data[i][4]) for i in range(1,len(table_data))]
    if(max(p_values) > significance_level): 
        column_to_remove = p_values.index(max(p_values))
        print("Removing column",included_columns[column_to_remove])
        del included_columns[column_to_remove]
    else:
        finished = True
print("Included columns are ",included_columns)
# Out:
# Removing column 2
# Removing column 23
# Removing column 21
# Removing column 46
# Removing column 40
# Removing column 48
# Removing column 1
# Removing column 39
# Removing column 43
# Removing column 41
# Removing column 14
# Removing column 18
# Removing column 52
# Removing column 35
# Removing column 37
# Removing column 22
# Removing column 42
# Removing column 31
# Removing column 53
# Removing column 17
# Removing column 30
# Removing column 20
# Removing column 24
# Removing column 34
# Removing column 33
# Removing column 29
# Removing column 49
# Removing column 54
# Removing column 56
# Removing column 27
# Removing column 45
# Removing column 26
# Removing column 47
# Removing column 28
# Removing column 25
# Removing column 36
# Removing column 32
# Removing column 7
# Removing column 6
# Removing column 9
# Removing column 5
# Removing column 10
# Removing column 44
# Removing column 15
# Removing column 19
# Removing column 38
# Removing column 13
# Removing column 16
# Removing column 50
# Removing column 8
# Removing column 3
# Removing column 58
# Removing column 60
# Removing column 11
# Included columns are  [0, 4, 12, 51, 55, 57, 59]

# %% [markdown]
# #### Step 5 (Use available features to build the model

# %%
#Modifying X according to results of backward elimination
X = X[:,included_columns]
X_train, X_test, Y_train, Y_test = cv.train_test_split(X,Y,test_size=0.25,random_state=0)
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
regressor.score(X_test,Y_test) #Score with all-in model
# Out:
# 4.901781930255478e-05
